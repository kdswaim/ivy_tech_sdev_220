# %% [markdown]
# 7.4 - make things list

# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# 7.5 - capitalize cinderella

# %%
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.6 - all uppercase for mozzarella

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.7 - delete salmonella

# %%
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# 9.1 - Define good function, return list

# %%
def good():
    return ['Harry', 'Ron', 'Hermoine']

# %% [markdown]
# 9.2 - Define generator function get_odds(), returning odd numbers from range(10); for loop to find and print third value returned

# %%
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number
