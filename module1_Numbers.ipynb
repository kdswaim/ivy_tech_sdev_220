# %% [markdown]
# Exercise 3.1 - Seconds in an hour

# %%
60 * 60
# Out:
# 3600

# %% [markdown]
# 3.2 - assign the variable

# %%
seconds_per_hour = 3600

# %% [markdown]
# 3.3 - calculate seconds in a day using seconds_per_hour

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# 3.4 - assign result to seconds_per_hour

# %%
seconds_per_day = 86400

# %% [markdown]
# 3.5 - seconds per day divided by seconds per hour (floating-point)

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# 3.6 - divide seconds per day by seconds per hour (integer division)

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Agreed with floating-point value? Y
